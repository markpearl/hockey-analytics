# %%
import requests
import pandas as pd

yes_username = "maryna.kalinina@brookfieldrenewable.com"
yes_pw = "Ygpc5x$eFbXWXvA"
yes_auth = (yes_username, yes_pw)
#distance_api_resp = requests.get("https://services.yesenergy.com/PS/rest/transoutage//ERCOT",auth=yes_auth)

# %%
gen_outages_resp = requests.get("https://services.yesenergy.com/PS/rest/generationoutage/ERCOT?&startdate=2017-04-01&enddate=2022-04-07&source=IIR,ERCOT,NRC&datetype=START&outagetype=Planned,Unplanned&outagestates=Ongoing,Past,Future,Cancelled",auth=yes_auth)

#from io import StringIO
#import pandas as pd
#distance_df= pd.read_csv(StringIO(distance_api_resp.text))
#distance_df.head()

# %%
distance_resp = requests.get("https://services.yesenergy.com/PS/rest/objects/distance/10004202606?miles=10&objecttype=facility",auth=yes_auth)
distance_df = pd.read_html(distance_resp.text, flavor="lxml")[0]
distance_df
# Out:
#      ANCHOR_OBJECTID ANCHOR_NAME ANCHOR_TYPE ANCHOR_ISO  RELATED_OBJECTID  \
# 0        10004202606       NBOHR     station      ERCOT       10000810765
# 1        10004202606       NBOHR     station      ERCOT       10000810766
# 2        10004202606       NBOHR     station      ERCOT       10002484861
# 3        10004202606       NBOHR     station      ERCOT       10002540853
# 4        10004202606       NBOHR     station      ERCOT       10002556284
# ..               ...         ...         ...        ...               ...
# 267      10004202606       NBOHR     station      ERCOT       10004202617
# 268      10004202606       NBOHR     station      ERCOT       10004212340
# 269      10004202606       NBOHR     station      ERCOT       10015883401
# 270      10004202606       NBOHR     station      ERCOT       10016032566
# 271      10004202606       NBOHR     station      ERCOT       10016246767
#
#                     RELATED_NAME RELATED_TYPE RELATED_ISO  DISTANCE
# ...

# %%
stations_resp = requests.get("https://services.yesenergy.com/PS/rest/objects/stations/ERCOT",auth=yes_auth)
stations_df = pd.read_html(stations_resp.text, flavor="lxml")[0]

# %%
stations_df[stations_df['STATIONNAME'].str.contains("PLAINS")]
# Out:
#          OBJECTID   STATIONNAME  ZONE    ISO
# 1235  10000700255  CROSS PLAINS  WEST  ERCOT

# %%
trans_outage_const_resp = requests.get("https://services.yesenergy.com/PS/rest/transoutage/ercot",auth=yes_auth)
trans_outage_const_df = pd.read_html(trans_outage_const_resp.text, flavor="lxml")[0]

# %%
trans_outage_const_df.to_csv('trans_outages.csv')

# %%
pricenodes_resp = requests.get("https://services.yesenergy.com/PS/rest/objects/pricenodes/ERCOT",auth=yes_auth)
pricenodes_df = pd.read_html(pricenodes_resp.text, flavor="lxml")[0]
pricenodes_df
# Out:
#         OBJECTID      NODENAME     ZONE  ZONEID   NODETYPE SUBSTATION  \
# 0    10002233425  ACACIA_UNIT1     WEST     NaN  GENERATOR     ACACIA
# 1    10002909619          AEEC     WEST     NaN  GENERATOR       AEEC
# 2    10016736809   AJAXWIND_RN     WEST     NaN  GENERATOR        NaN
# 3    10016818139  ALGOD_ALL_RN    SOUTH     NaN  GENERATOR        NaN
# 4    10016433362      ALVIN_RN  HOUSTON     NaN  GENERATOR        NaN
# ..           ...           ...      ...     ...        ...        ...
# 927  10016747526   WOV_BESS_RN     WEST     NaN  GENERATOR   WOV_BESS
# 928  10016027199  WRSBES_BESS1     WEST     NaN  GENERATOR        NaN
# 929  10016662167    WRSBES_LD1     WEST     NaN       LOAD     WRSBES
# 930  10016024608  W_PECO_UNIT1     WEST     NaN  GENERATOR    W_PECOS
# 931  10016009671      X443ESRN    SOUTH     NaN  GENERATOR   X443ESS1
#
#      VOLTAGE  EQUIPMENT      FIRST_DART_DATE       LAST_DART_DATE  \
# ...

# %%
pricenodes_df[pricenodes_df['NODENAME'].str.contains("SPLAIN")]
# Out:
#         OBJECTID    NODENAME  ZONE  ZONEID   NODETYPE SUBSTATION  VOLTAGE  \
# 775  10002876989  SPLAIN1_RN  WEST     NaN  GENERATOR    SPLAIN1      NaN
# 776  10002910934  SPLAIN2_RN  WEST     NaN  GENERATOR    SPLAIN2      NaN
#
#      EQUIPMENT      FIRST_DART_DATE       LAST_DART_DATE  \
# 775        NaN  08/19/2015 01:00:00  04/26/2022 00:00:00
# 776        NaN  01/20/2016 01:00:00  04/26/2022 00:00:00
#
#     NEAREST_WEATHERSTATION  WEATHERSTATIONID    ISO
# 775      TX - Lubbock/Intl      1.000036e+10  ERCOT
# 776      TX - Lubbock/Intl      1.000036e+10  ERCOT

# %%
pricenodes_df[pricenodes_df['NODENAME'].str.contains("RSK_RN")]
# Out:
#         OBJECTID NODENAME  ZONE  ZONEID   NODETYPE SUBSTATION  VOLTAGE  \
# 720  10002859559   RSK_RN  WEST     NaN  GENERATOR   W_BK_345      NaN
#
#      EQUIPMENT      FIRST_DART_DATE       LAST_DART_DATE  \
# 720        NaN  04/15/2015 01:00:00  04/26/2022 00:00:00
#
#     NEAREST_WEATHERSTATION  WEATHERSTATIONID    ISO
# 720    TX - Midland-Odessa      1.000036e+10  ERCOT

# %%
weatherstations_resp = requests.get("https://services.yesenergy.com/PS/rest/objects/weatherstations/ERCOT",auth=yes_auth)
weatherstations_df = pd.read_html(weatherstations_resp.text, flavor="lxml")[0]
weatherstations_df
# Out:
#        OBJECTID   WBAN      WMO  ICAO  FAA  \
# 0   10000355044  23050  72365.0  KABQ  ABQ
# 1   10000356939  23009  72268.0  KROW  ROW
# 2   10000355043  13962  72266.0  KABI  ABI
# 3   10000355099  23047  72363.0  KAMA  AMA
# 4   10000355160  13904      NaN  KAUS  AUS
# 5   10000355279  12917  72241.0  KBPT  BPT
# 6   10000355284  12919  72250.0  KBRO  BRO
# 7   10000355400   3904      NaN  KCLL  CLL
# 8   10000355475  53902      NaN  KCXO  CXO
# 9   10000355444  12924  72251.0  KCRP  CRP
# 10  10000355513   3927  72259.0  KDFW  DFW
# 11  10000355493  13960  72258.0  KDAL  DAL
# 12  10000355558  22004  72261.0  KDRT  DRT
# 13  10000355640  23044  72270.0  KELP  ELP
# 14  10000355775  23091      NaN  KFST  FST
# 15  10000355843  12923  72242.0  KGLS  GLS
# 16  10000355812  23055      NaN  KGDP  GDP
# 17  10000356032  12960  72243.0  KIAH  IAH
# 18  10000356251  12920  72252.0  KLRD  LRD
# 19  10000356180  23042  72267.0  KLBB  LBB
# 20  10000356426  93035      NaN  KMRF  MRF
# ...

# %%
transoutageconstraint_resp = requests.get("https://services.yesenergy.com/PS/rest/transoutage/ERCOT?market=RT&startdate=4/10/2022&enddate=4/27/2022&sort=7&desc",auth=yes_auth)
transoutageconstraint_df = pd.read_html(transoutageconstraint_resp.text, flavor="lxml")[0]
transoutageconstraint_df
# Out:
#          ISO                                 FACILITY  \
# 0      ERCOT         WICKETT-WLFSW 138KV 138_WIC_OWF1
# 1      ERCOT  EASTMUND-BOBWHITE 138KV BOBWHI_EASTMU11
# 2      ERCOT  BOBWHITE-MARGARET 138KV BOBWHI_MARGAR11
# 3      ERCOT        PAUL-BOBWHITE 138KV BOBWHI_PAUL11
# 4      ERCOT            LPLMK-LPLCO 69KV LPLMK_LPLCO1
# ...      ...                                      ...
# 11338  ERCOT                    LPLER 69KV ER150 BRKR
# 11339  ERCOT                W_FD_345 345KV 106-82 DSC
# 11340  ERCOT                        PSA 138KV TR2A LD
# 11341  ERCOT                      FGPOD 138KV J41 DSC
# 11342  ERCOT                     NATDAM 138KV PS1 DSC
#
#                     FROMSTATION TOSTATION   KV FROMZONE TOZONE FACILITY_TYPE  \
# 0                   WICKETT TNP     WLFSW  138     WEST   WEST          LINE
# 1                   MUNDAY EAST  BOBWHITE  138     WEST   WEST          LINE
# 2                      BOBWHITE  MARGARET  138     WEST   WEST          LINE
# ...

# %%
#Facility API
facility_resp = requests.get("https://services.yesenergy.com/PS/rest/objects/facilities/ERCOT" ,auth=yes_auth)
facility_df = pd.read_html(facility_resp.text, flavor="lxml")[0]
facility_df

# %%
facility_df = pd.read_html(facility_resp.text, flavor="lxml")[0]
facility_df
# Out:
#            OBJECTID           FACILITYNAME FACILITYTYPE  VOLTAGE     ZONE  \
# 0       10002849761           - 0KV AJO_ZO         LINE    345.0    SOUTH
# 1       10004218358           - 0KV EASTEX         LINE    345.0    NORTH
# 2       10004237139           - 0KV NELRIO         LINE    345.0    SOUTH
# 3       10016497883           - 0KV PIGSOL         LINE    138.0     WEST
# 4       10015886238           - 0KV REDTAP         LINE    138.0    SOUTH
# ...             ...                    ...          ...      ...      ...
# 129209  10001829219    _AK 138KV XT01 XFMR         XFMR    138.0  HOUSTON
# 129210  10001829220  _AK 138KV _AKL018 DSC          DSC    138.0      NaN
# 129211  10000792363  _AK 138KV _AKL019 DSC          DSC    138.0      NaN
# 129212  10001829471     _AK 13KV G010 BRKR         BRKR     13.0      NaN
# 129213  10001829472     _AK 13KV L010 BRKR         BRKR     13.0      NaN
#
#         FROMSTATIONID              FROMSTATIONNAME   TOSTATIONID  \
# ...

# %%
facility_df[facility_df['FACILITYNAME'].str.contains("W_BK_345")]
# Out:
#            OBJECTID                             FACILITYNAME FACILITYTYPE  \
# 36379   10016033511   EINSTEIN-W_BK_345 345KV EINSTEIN_BEARK         LINE
# 36380   10004065408  EINSTEIN-W_BK_345 345KV EINSTEIN_BEARK1         LINE
# 99617   10002854313    RSNAKE-W_BK_345 345KV RSNAKE_BEARKAT1         LINE
# 127477  10002739881                W_BK_345 345KV 105-12 DSC          DSC
# 127478  10002739883                W_BK_345 345KV 105-13 DSC          DSC
# 127479  10004060451               W_BK_345 345KV 105-20 BRKR         BRKR
# 127480  10002739882                W_BK_345 345KV 105-21 DSC          DSC
# 127481  10004060452                W_BK_345 345KV 105-31 DSC          DSC
# 127482  10004176017               W_BK_345 345KV 105-40 BRKR         BRKR
# 127483  10004176018                W_BK_345 345KV 105-41 DSC          DSC
# 127484  10002383201                W_BK_345 345KV 105-42 DSC          DSC
# 127485  10004176016                W_BK_345 345KV 105-43 DSC          DSC
# ...

# %%
transoutageconstraint_df
transoutageconstraint_df[transoutageconstraint_df['FROMSTATION'].str.contains("W_BK_345")]
# Out:
#         ISO                    FACILITY FROMSTATION TOSTATION   KV FROMZONE  \
# 6487  ERCOT   W_BK_345 345KV 105-52 DSC    W_BK_345       NaN  345     WEST
# 6489  ERCOT   W_BK_345 345KV 105-61 DSC    W_BK_345       NaN  345     WEST
# 6490  ERCOT  W_BK_345 345KV 105-50 BRKR    W_BK_345       NaN  345     WEST
# 6492  ERCOT   W_BK_345 345KV 105-62 DSC    W_BK_345       NaN  345     WEST
# 6493  ERCOT  W_BK_345 345KV 105-60 BRKR    W_BK_345       NaN  345     WEST
# 6496  ERCOT   W_BK_345 345KV 105-51 DSC    W_BK_345       NaN  345     WEST
#
#      TOZONE FACILITY_TYPE    TYPE            TYPE_DETAIL  ... OPEN_CLOSE  \
# 6487    NaN           DSC  Forced  Unavoidable Extension  ...        NaN
# 6489    NaN           DSC  Forced  Unavoidable Extension  ...        NaN
# 6490    NaN          BRKR  Forced  Unavoidable Extension  ...        NaN
# 6492    NaN           DSC  Forced  Unavoidable Extension  ...        NaN
# ...

# %%
#Facility API
timeseries_resp = requests.get("https://services.yesenergy.com/PS/rest/timeseries/multiple.csv?items=DALMP:8445784,DALMP:970242670,DALMP:RSK_RN,DALMP:SPLAIN1_RN,EIA930_NET_GEN_COAL:10000712973,EIA930_NET_GEN_COAL:10003947611,EIA930_NET_GEN_GAS:10000712973,EIA930_NET_GEN_GAS:10003947611,EIA930_NET_GEN_NUC:10000712973,EIA930_NET_GEN_NUC:10003947611,EIA930_NET_GEN_SUN:10000712973,EIA930_NET_GEN_SUN:10003947611,EIA930_NET_GEN_WAT:10000712973,EIA930_NET_GEN_WAT:10003947611,EIA930_NET_GEN_WIND:10000712973,EIA930_NET_GEN_WIND:10003947611,GEN_RESOURCE:10000712969,GEN_RESOURCE:10000712970,GEN_RESOURCE:10000712971,GEN_RESOURCE:10000712972,GEN_RESOURCE:10000756298,GEN_RESOURCE_DELTA:10000756298,GEN_RESOURCE_PREV:10000756298,GENERATION_SOLAR_RT:10000002572,GENERATION_SOLAR_RT:10000328798,GENERATION_SOLAR_RT:10000611850,GENERATION_SOLAR_RT:10000712973,GENERATION_SOLAR_RT:10002494908,GENERATION_SOLAR_RT:10002494909,GENERATION_SOLAR_RT:10002494910,GENERATION_SOLAR_RT:10002510711,IIR_ISO_COAL_TOT:10000756293,IIR_ISO_COAL_TOT:10000756294,IIR_ISO_COAL_TOT:10000756295,IIR_ISO_COAL_TOT:10000756296,IIR_ISO_COAL_TOT:10000756297,IIR_ISO_COAL_TOT:10000756298,IIR_ISO_COAL_TOT:10001982431,IIR_ISO_COAL_TOT:10002487012,IIR_ISO_GAS_TOT:10000756293,IIR_ISO_GAS_TOT:10000756294,IIR_ISO_GAS_TOT:10000756295,IIR_ISO_GAS_TOT:10000756296,IIR_ISO_GAS_TOT:10000756297,IIR_ISO_GAS_TOT:10000756298,IIR_ISO_GAS_TOT:10001982431,IIR_ISO_GAS_TOT:10002487012,IIR_ISO_NUC_TOT:10000756293,IIR_ISO_NUC_TOT:10000756294,IIR_ISO_NUC_TOT:10000756295,IIR_ISO_NUC_TOT:10000756296,IIR_ISO_NUC_TOT:10000756297,IIR_ISO_NUC_TOT:10000756298,IIR_ISO_NUC_TOT:10001982431,IIR_ISO_NUC_TOT:10002487012,IIR_ISO_OIL_TOT:10000756293,IIR_ISO_OIL_TOT:10000756294,IIR_ISO_OIL_TOT:10000756295,IIR_ISO_OIL_TOT:10000756296,IIR_ISO_OIL_TOT:10000756297,IIR_ISO_OIL_TOT:10000756298,IIR_ISO_OIL_TOT:10001982431,IIR_ISO_OIL_TOT:10002487012,IIR_ISO_OTH_TOT:10000756293,IIR_ISO_OTH_TOT:10000756294,IIR_ISO_OTH_TOT:10000756295,IIR_ISO_OTH_TOT:10000756296,IIR_ISO_OTH_TOT:10000756297,IIR_ISO_OTH_TOT:10000756298&agglevel=hour&startdate=2017-01-01&enddate=2017-07-01&showiso=Y&showid=Y&showname=Y&timezone=utc" ,auth=yes_auth)

# %%
timeseries_resp.text
# Out:
# 'DATETIME,AEP 8445784 PJMISO (DALMP),EKPC 970242670 PJMISO (DALMP),RSK_RN 10002859559 ERCOT (DALMP),SPLAIN1_RN 10002876989 ERCOT (DALMP),ERCOT 10000712973 ERCOT (EIA930_NET_GEN_COAL),United States Lower 48 10003947611 PJMISO (EIA930_NET_GEN_COAL),ERCOT 10000712973 ERCOT (EIA930_NET_GEN_GAS),United States Lower 48 10003947611 PJMISO (EIA930_NET_GEN_GAS),ERCOT 10000712973 ERCOT (EIA930_NET_GEN_NUC),United States Lower 48 10003947611 PJMISO (EIA930_NET_GEN_NUC),ERCOT 10000712973 ERCOT (EIA930_NET_GEN_SUN),United States Lower 48 10003947611 PJMISO (EIA930_NET_GEN_SUN),ERCOT 10000712973 ERCOT (EIA930_NET_GEN_WAT),United States Lower 48 10003947611 PJMISO (EIA930_NET_GEN_WAT),ERCOT 10000712973 ERCOT (EIA930_NET_GEN_WIND),United States Lower 48 10003947611 PJMISO (EIA930_NET_GEN_WIND),NORTH (ERCOT) 10000712969 ERCOT (GEN_RESOURCE),SOUTH 10000712970 ERCOT (GEN_RESOURCE),WEST (ERCOT) 10000712971 ERCOT (GEN_RESOURCE),HOUSTON 10000712972 ERCOT (GEN_RESOURCE),ERCOT 10000756298 ERCOT (GEN_RESOURC
# ...

# %%
f"http://www.wsitrader.com/Services/CSVDownloadService.svc/GetHistoricalObservations?Account={self.wsi_username}&Password={self.wsi_password}&Profile={self.wsi_account}&TempUnits={degree}&HistoricalProductID={self.HistoricalProductID}&StartDate={self.StartDate}&EndDate={self.EndDate}&CityIds[]={site_id}&DataTypes[]={self.data_types}"
                  )
